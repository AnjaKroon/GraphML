# %%
# !pip install PyGSP
# !pip install tensorboardx
# !pip install torch
# !pip install neuralforecast
# Out:
# Requirement already satisfied: PyGSP in /home/victor/anaconda3/lib/python3.11/site-packages (0.5.1)
# Requirement already satisfied: numpy in /home/victor/anaconda3/lib/python3.11/site-packages (from PyGSP) (1.26.4)
# Requirement already satisfied: scipy in /home/victor/anaconda3/lib/python3.11/site-packages (from PyGSP) (1.11.4)
# Requirement already satisfied: tensorboardx in /home/victor/anaconda3/lib/python3.11/site-packages (2.6.2.2)
# Requirement already satisfied: numpy in /home/victor/anaconda3/lib/python3.11/site-packages (from tensorboardx) (1.26.4)
# Requirement already satisfied: packaging in /home/victor/anaconda3/lib/python3.11/site-packages (from tensorboardx) (23.1)
# Requirement already satisfied: protobuf>=3.20 in /home/victor/anaconda3/lib/python3.11/site-packages (from tensorboardx) (3.20.3)
# Requirement already satisfied: torch in /home/victor/anaconda3/lib/python3.11/site-packages (2.3.1)
# Requirement already satisfied: filelock in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/victor/anaconda3/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.5.40)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/victor/anaconda3/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: neuralforecast in /home/victor/anaconda3/lib/python3.11/site-packages (1.7.2)
# Requirement already satisfied: coreforecast>=0.0.6 in /home/victor/anaconda3/lib/python3.11/site-packages (from neuralforecast) (0.0.10)
# Requirement already satisfied: fsspec in /home/victor/anaconda3/lib/python3.11/site-packages (from neuralforecast) (2023.10.0)
# Requirement already satisfied: numpy>=1.21.6 in /home/victor/anaconda3/lib/python3.11/site-packages (from neuralforecast) (1.26.4)
# Requirement already satisfied: pandas>=1.3.5 in /home/victor/anaconda3/lib/python3.11/site-packages (from neuralforecast) (2.1.4)
# Requirement already satisfied: torch>=2.0.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from neuralforecast) (2.3.1)
# Requirement already satisfied: pytorch-lightning>=2.0.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from neuralforecast) (2.3.0)
# Requirement already satisfied: ray>=2.2.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from ray[tune]>=2.2.0->neuralforecast) (2.24.0)
# Requirement already satisfied: optuna in /home/victor/anaconda3/lib/python3.11/site-packages (from neuralforecast) (3.6.1)
# Requirement already satisfied: utilsforecast>=0.0.25 in /home/victor/anaconda3/lib/python3.11/site-packages (from neuralforecast) (0.1.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/victor/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.5->neuralforecast) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.5->neuralforecast) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.5->neuralforecast) (2023.3)
# Requirement already satisfied: tqdm>=4.57.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from pytorch-lightning>=2.0.0->neuralforecast) (4.65.0)
# Requirement already satisfied: PyYAML>=5.4 in /home/victor/anaconda3/lib/python3.11/site-packages (from pytorch-lightning>=2.0.0->neuralforecast) (6.0.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from pytorch-lightning>=2.0.0->neuralforecast) (1.4.0.post0)
# Requirement already satisfied: packaging>=20.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from pytorch-lightning>=2.0.0->neuralforecast) (23.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from pytorch-lightning>=2.0.0->neuralforecast) (4.9.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from pytorch-lightning>=2.0.0->neuralforecast) (0.11.2)
# Requirement already satisfied: click>=7.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (8.1.7)
# Requirement already satisfied: filelock in /home/victor/anaconda3/lib/python3.11/site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (3.13.1)
# Requirement already satisfied: jsonschema in /home/victor/anaconda3/lib/python3.11/site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (4.19.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (1.0.3)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /home/victor/anaconda3/lib/python3.11/site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (3.20.3)
# Requirement already satisfied: aiosignal in /home/victor/anaconda3/lib/python3.11/site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (1.2.0)
# Requirement already satisfied: frozenlist in /home/victor/anaconda3/lib/python3.11/site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (1.4.0)
# Requirement already satisfied: requests in /home/victor/anaconda3/lib/python3.11/site-packages (from ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2.31.0)
# Requirement already satisfied: tensorboardX>=1.9 in /home/victor/anaconda3/lib/python3.11/site-packages (from ray[tune]>=2.2.0->neuralforecast) (2.6.2.2)
# Requirement already satisfied: pyarrow>=6.0.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from ray[tune]>=2.2.0->neuralforecast) (14.0.2)
# Requirement already satisfied: sympy in /home/victor/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->neuralforecast) (1.12)
# Requirement already satisfied: networkx in /home/victor/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->neuralforecast) (3.1)
# Requirement already satisfied: jinja2 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->neuralforecast) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->neuralforecast) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->neuralforecast) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->neuralforecast) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->neuralforecast) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->neuralforecast) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->neuralforecast) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->neuralforecast) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->neuralforecast) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->neuralforecast) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->neuralforecast) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->neuralforecast) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from torch>=2.0.0->neuralforecast) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/victor/anaconda3/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.0->neuralforecast) (12.5.40)
# Requirement already satisfied: alembic>=1.5.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from optuna->neuralforecast) (1.13.1)
# Requirement already satisfied: colorlog in /home/victor/anaconda3/lib/python3.11/site-packages (from optuna->neuralforecast) (6.8.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from optuna->neuralforecast) (2.0.25)
# Requirement already satisfied: Mako in /home/victor/anaconda3/lib/python3.11/site-packages (from alembic>=1.5.0->optuna->neuralforecast) (1.3.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/victor/anaconda3/lib/python3.11/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (3.9.3)
# Requirement already satisfied: setuptools in /home/victor/anaconda3/lib/python3.11/site-packages (from lightning-utilities>=0.8.0->pytorch-lightning>=2.0.0->neuralforecast) (68.2.2)
# Requirement already satisfied: six>=1.5 in /home/victor/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->neuralforecast) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/victor/anaconda3/lib/python3.11/site-packages (from sqlalchemy>=1.3.0->optuna->neuralforecast) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=2.0.0->neuralforecast) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/victor/anaconda3/lib/python3.11/site-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/victor/anaconda3/lib/python3.11/site-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from jsonschema->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (0.10.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/victor/anaconda3/lib/python3.11/site-packages (from requests->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/victor/anaconda3/lib/python3.11/site-packages (from requests->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from requests->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/victor/anaconda3/lib/python3.11/site-packages (from requests->ray>=2.2.0->ray[tune]>=2.2.0->neuralforecast) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /home/victor/anaconda3/lib/python3.11/site-packages (from sympy->torch>=2.0.0->neuralforecast) (1.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/victor/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (1.9.3)

# %%
# !pip install -U giotto-tda
# Out:
# Requirement already satisfied: giotto-tda in /home/victor/anaconda3/lib/python3.11/site-packages (0.6.2)
# Requirement already satisfied: numpy>=1.19.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from giotto-tda) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from giotto-tda) (1.11.4)
# Requirement already satisfied: joblib>=0.16.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from giotto-tda) (1.2.0)
# Requirement already satisfied: scikit-learn==1.3.2 in /home/victor/anaconda3/lib/python3.11/site-packages (from giotto-tda) (1.3.2)
# Requirement already satisfied: giotto-ph>=0.2.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from giotto-tda) (0.2.4)
# Requirement already satisfied: pyflagser>=0.4.3 in /home/victor/anaconda3/lib/python3.11/site-packages (from giotto-tda) (0.4.7)
# Requirement already satisfied: igraph>=0.9.8 in /home/victor/anaconda3/lib/python3.11/site-packages (from giotto-tda) (0.11.5)
# Requirement already satisfied: plotly>=4.8.2 in /home/victor/anaconda3/lib/python3.11/site-packages (from giotto-tda) (5.9.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from giotto-tda) (7.6.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from scikit-learn==1.3.2->giotto-tda) (2.2.0)
# Requirement already satisfied: texttable>=1.6.2 in /home/victor/anaconda3/lib/python3.11/site-packages (from igraph>=0.9.8->giotto-tda) (1.7.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.5.1->giotto-tda) (6.28.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.5.1->giotto-tda) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.5.1->giotto-tda) (5.7.1)
# Requirement already satisfied: nbformat>=4.2.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.5.1->giotto-tda) (5.9.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.5.1->giotto-tda) (3.5.2)
# Requirement already satisfied: ipython>=4.0.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.5.1->giotto-tda) (8.20.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.5.1->giotto-tda) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from plotly>=4.8.2->giotto-tda) (8.2.2)
# Requirement already satisfied: comm>=0.1.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->giotto-tda) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->giotto-tda) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->giotto-tda) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->giotto-tda) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->giotto-tda) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/victor/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->giotto-tda) (1.6.0)
# Requirement already satisfied: packaging in /home/victor/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->giotto-tda) (23.1)
# Requirement already satisfied: psutil in /home/victor/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->giotto-tda) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->giotto-tda) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->giotto-tda) (6.3.3)
# Requirement already satisfied: decorator in /home/victor/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->giotto-tda) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->giotto-tda) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->giotto-tda) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->giotto-tda) (2.15.1)
# Requirement already satisfied: stack-data in /home/victor/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->giotto-tda) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/victor/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->giotto-tda) (4.8.0)
# Requirement already satisfied: fastjsonschema in /home/victor/anaconda3/lib/python3.11/site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->giotto-tda) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/victor/anaconda3/lib/python3.11/site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->giotto-tda) (4.19.2)
# Requirement already satisfied: notebook>=4.4.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (7.0.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.1->giotto-tda) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->giotto-tda) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/victor/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->giotto-tda) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/victor/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->giotto-tda) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.5.1->giotto-tda) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.5.1->giotto-tda) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.5.1->giotto-tda) (3.10.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in /home/victor/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/victor/anaconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (0.2.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/victor/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.5.1->giotto-tda) (0.7.0)
# Requirement already satisfied: wcwidth in /home/victor/anaconda3/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets>=7.5.1->giotto-tda) (0.2.5)
# Requirement already satisfied: executing in /home/victor/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->giotto-tda) (0.8.3)
# Requirement already satisfied: asttokens in /home/victor/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->giotto-tda) (2.0.5)
# Requirement already satisfied: pure-eval in /home/victor/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.1->giotto-tda) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (4.2.0)
# Requirement already satisfied: argon2-cffi in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (21.3.0)
# Requirement already satisfied: jinja2 in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (3.1.3)
# Requirement already satisfied: jupyter-events>=0.6.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (7.10.0)
# Requirement already satisfied: overrides in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (7.4.0)
# Requirement already satisfied: prometheus-client in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (0.14.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (0.17.1)
# Requirement already satisfied: websocket-client in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (0.58.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (0.9.6)
# Requirement already satisfied: requests>=2.31 in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (2.31.0)
# Requirement already satisfied: six>=1.5 in /home/victor/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.5.1->giotto-tda) (1.16.0)
# Requirement already satisfied: idna>=2.8 in /home/victor/anaconda3/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (1.3.0)
# Requirement already satisfied: pytz>=2015.7 in /home/victor/anaconda3/lib/python3.11/site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (2023.3.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from jinja2->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (2.1.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/victor/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (4.1.0)
# Requirement already satisfied: defusedxml in /home/victor/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/victor/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/victor/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (1.5.0)
# Requirement already satisfied: tinycss2 in /home/victor/anaconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (1.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/victor/anaconda3/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/victor/anaconda3/lib/python3.11/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (2024.2.2)
# Requirement already satisfied: argon2-cffi-bindings in /home/victor/anaconda3/lib/python3.11/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (21.2.0)
# Requirement already satisfied: webencodings in /home/victor/anaconda3/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (0.5.1)
# Requirement already satisfied: fqdn in /home/victor/anaconda3/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (1.5.1)
# Requirement already satisfied: isoduration in /home/victor/anaconda3/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/victor/anaconda3/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (2.1)
# Requirement already satisfied: uri-template in /home/victor/anaconda3/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /home/victor/anaconda3/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (24.6.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/victor/anaconda3/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /home/victor/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (2.5)
# Requirement already satisfied: pycparser in /home/victor/anaconda3/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /home/victor/anaconda3/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->giotto-tda) (1.2.3)

# %%
import torch
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import networkx as nx
from gtda.graphs import KNeighborsGraph
import itertools

#import os
#import sys
#sys.path.append(os.path.join(os.path.dirname(__file__), '..'))

from importlib import reload
import Model1
reload(Model1)
import Model2
reload(Model2)
import Model3
reload(Model3)

from utils import GraphRNN_dataset, GraphRNN_DataSampler
from Model1 import Temporal_Processing
from Model2 import STGCNChebGraphConv
from Model3 import ParametricNetWithPooling
import matplotlib.pyplot as plt

# %%
print("Starting training run...")
flow_dataset = "../data/daily_county2county_2019_01_01.csv"
epi_dataset = "../data_epi/epidemiology.csv"
epi_dates = ["2020-06-09", "2020-06-10", "2020-06-11", "2020-06-12",
             "2020-06-13", "2020-06-14", "2020-06-15", "2020-06-16",
             "2020-06-17", "2020-06-18", "2020-06-19", "2020-06-20",
             "2020-06-21", "2020-06-22", "2020-06-23", "2020-06-24",
                "2020-06-25", "2020-06-26", "2020-06-27", "2020-06-28",
                "2020-06-29", "2020-06-30", "2020-07-01", "2020-07-02",
                "2020-07-03", "2020-07-04", "2020-07-05", "2020-07-06",
                "2020-07-07", "2020-07-08", "2020-07-09", "2020-07-10",
                "2020-07-11", "2020-07-12", "2020-07-13", "2020-07-14",
                "2020-07-15", "2020-07-16", "2020-07-17", "2020-07-18",
                "2020-07-19", "2020-07-20", "2020-07-21", "2020-07-22",
                "2020-07-23", "2020-07-24", "2020-07-25", "2020-07-26",
                "2020-07-27", "2020-07-28", "2020-07-29", "2020-07-30"
             ]


input_hor = 5
pred_hor = 1
print("Loading data...")
data_set = GraphRNN_dataset(epi_dates = epi_dates,
                            flow_dataset = flow_dataset,
                            epi_dataset = epi_dataset,
                            input_hor=input_hor,
                            pred_hor=pred_hor,
                            fake_data=False)
# data_set.visualize(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# data_sampler = GraphRNN_DataSampler(data_set, input_hor=input_hor, pred_hor=pred_hor)
data_loader = torch.utils.data.DataLoader(data_set, batch_size=5, pin_memory=True, num_workers=0, shuffle=True)

print("Data loaded.")
input_edge_weights, input_node_data, target_edge_weights, target_node_data = next(iter(data_loader))
# Out:
# Starting training run...
# Loading data...
# Flow data shape:      geoid_o  geoid_d      lng_o      lat_o      lng_d      lat_d        date  \
# 9       1001     1021 -86.642757  32.534921 -86.718814  32.847853  2019-01-01
# 21      1001     1051 -86.642757  32.534921 -86.149147  32.596648  2019-01-01
# 38      1001     1101 -86.642757  32.534921 -86.207614  32.220258  2019-01-01
# 265     1003     1035 -87.749845  30.660974 -86.993681  31.429267  2019-01-01
# 274     1003     1053 -87.749845  30.660974 -87.161620  31.126123  2019-01-01
#
#      visitor_flows  pop_flows
# 9         0.463154   0.550704
# 21        0.688665   0.725945
# 38        0.647880   0.694244
# 265       0.379613   0.474777
# 274       0.495607   0.564922
# Signals[0] data shape:          geoid_o        date  new_confirmed  infection_gone
# 9897156     2013  2020-06-09            NaN             0.0
# 9897865     2016  2020-06-09            0.0             0.0
# 9898658     2020  2020-06-09            5.0             1.0
# 9899425     2050  2020-06-09            0.0             0.0
# 9900826     2070  2020-06-09            0.0             0.0
# Number of time steps: 52
# Number of unique nodes with features: 3070
# 100%|███████████████████████████████████████████████████████████████████████████| 14328/14328 [00:03<00:00, 3993.52it/s]
# node_data: torch.Size([52, 3070, 1])
# edge_weights: torch.Size([52, 14328, 3])
# =====================================
# Number of unique nodes from final edges: 3070
# Number of unique nodes from signals: 3070
# Node IDs match between edges and signals
# =====================================
# Sparsity of node data:  0.36212728639438735
# Sparsity of edge weights:  0.0
# Data loaded.

# %%
#reimport models
import Model1
reload(Model1)
import Model2
reload(Model2)
import Model3
reload(Model3)
from utils import GraphRNN_dataset, GraphRNN_DataSampler
from Model1 import Temporal_Processing
from Model2 import STGCNChebGraphConv
from Model3 import ParametricNetWithPooling


models  = [Temporal_Processing(data_set.node_data_df,
                   n_nodes = data_set.n_nodes,
                   n_features = data_set.n_features,
                   h_size = 50,
                   f_out_size = 50,
                   fixed_edge_weights = input_edge_weights[0,0,:,:],
                   device=device,
                   dtype=torch.float32),
           STGCNChebGraphConv(n_nodes = data_set.n_nodes,
                   n_features = data_set.n_features,
                   h_size = 50,
                   f_out_size = 50,
                   fixed_edge_weights = input_edge_weights[0,0,:,:],
                   device=device,
                   dtype=torch.float32),
           ParametricNetWithPooling(n_nodes = data_set.n_nodes,
                   n_features = data_set.n_features,
                   h_size = 50,
                   f_out_size = 50,
                   fixed_edge_weights = input_edge_weights[0,0,:,:],
                   device=device,
                   dtype=torch.float32)
]
           

# torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
for model in models:
    # torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

    criterion = torch.nn.MSELoss().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.00045)


    torch.autograd.set_detect_anomaly(False)

    model.to(device)
    
    log_dir = './log'
    if not os.path.exists(log_dir):
        os.makedirs(log_dir)
    # Use torch.profiler to profile the model
    with torch.profiler.profile(
        activities=[
            torch.profiler.ProfilerActivity.CPU,
            torch.profiler.ProfilerActivity.CUDA,
        ],
        schedule=torch.profiler.schedule(wait=1, warmup=1, active=2, repeat=0),
        on_trace_ready=torch.profiler.tensorboard_trace_handler('./log'),
        record_shapes=True,
        profile_memory=False,
        with_stack=True
    ) as prof:
        print("Starting training with profiling...")
        losses, parameter_mag = train(model, data_loader,
                                  criterion, optimizer,
                                  pred_hor, device, n_epochs=250,
                                  save="model_state_dict.pth")
        print("Finished training with profiling.")


    # Verify that the log directory is populated
    if os.listdir(log_dir):
        print(f"Log files generated in {log_dir}")
    else:
        print(f"No log files found in {log_dir}")
    

    print("Storing model state...")
    torch.save(model.state_dict(), 'model_state_dict.pth')
    print("Model state stored.")
    print("Plotting losses...")
    plt.plot(losses)
    plt.xlabel("Iteration")
    plt.ylabel("Loss")
    plt.yscale("log")
    plt.show()
    
    print("Plotting parameter magnitudes...")
    plt.figure()
    plt.plot(parameter_mag["init_H"], label="init_H")
    plt.plot(parameter_mag["A"], label="A")
    plt.plot(parameter_mag["B"], label="B")
    plt.plot(parameter_mag["C"], label="C")
    plt.plot(parameter_mag["D"], label="D")
    plt.plot(parameter_mag["E"], label="E")
    plt.plot(parameter_mag["F"], label="F")
    plt.plot(parameter_mag["G"], label="G")
    
    plt.xlabel("Iteration")
    plt.ylabel("Parameter Magnitude")
    # plt.yscale("log")
    plt.legend()
    plt.show()
# Out:
# [AutoTCN]
# <neuralforecast.core.NeuralForecast object at 0x7f59d9ab9a50>
#                y
# time geoid_o
# 0    1001     10
#      1003      5
#      1005      2
#      1007      6
#      1009      2
# ...           ..
# 51   72145    13
#      72147     1
#      72149     0
#      72151     3
#      72153     5
#
# [159640 rows x 1 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ds'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 14
#      10 from Model2 import STGCNChebGraphConv
#      11 from Model3 import ParametricNetWithPooling
# ---> 14 models  = [Temporal_Processing(data_set.node_data_df,
#      15                    n_nodes = data_set.n_nodes,
#      16                    n_features = data_set.n_features,
#      17                    h_size = 50,
#      18                    f_out_size =50,
#      19                    fixed_edge_weights = input_edge_weights[0,0,:,:],
#      20                    device=device,
#      21                    dtype=torch.float32),
#      22            STGCNChebGraphConv(n_nodes = data_set.n_nodes,
#      23                    n_features = data_set.n_features,
#      24                    h_size = 50,
#      25                    f_out_size =50,
#      26                    fixed_edge_weights = input_edge_weights[0,0,:,:],
#      27                    device=device,
#      28                    dtype=torch.float32),
#      29            ParametricNetWithPooling(n_nodes = data_set.n_nodes,
#      30                    n_features = data_set.n_features,
#      31                    h_size = 50,
#      32                    f_out_size =50,
#      33                    fixed_edge_weights = input_edge_weights[0,0,:,:],
#      34                    device=device,
#      35                    dtype=torch.float32)
#      36 ]
#      39 # torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
#      40 for model in models:
#      41     # torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
#
# File /mnt/c/Users/Victor Gladys/Documents/Master/GraphML/ClassicalModels/Model1.py:19, in Temporal_Processing.__init__(self, df, n_nodes, n_features, h_size, f_out_size, fixed_edge_weights, device, dtype)
#      10 def __init__(self, df, n_nodes, n_features, h_size, f_out_size, fixed_edge_weights=None , device='cpu', dtype=torch.float32):
#      11     """ Initialize the Graph RNN
#      12     Args:
#      13         n_nodes (int): number of nodes in the graph
#    (...)
#      17         edge_weights (torch.Tensor): edge weights tensor of shape (batch, n_time_steps, n_edges, 3), per edge (node1 , node2, edge_feat)
#      18         """
# ---> 19     self.internal__init__(dataframe=df)
#
# File /mnt/c/Users/Victor Gladys/Documents/Master/GraphML/ClassicalModels/Model1.py:39, in Temporal_Processing.internal__init__(self, dataframe)
#      37 dataframe = dataframe.rename(columns={"time": "ds", "new_confirmed": "y"})
#      38 print(dataframe.loc[pd.IndexSlice[:,:], :])
# ---> 39 model.fit(dataframe)
#      40 forecasts = model.predict()
#
# File ~/anaconda3/lib/python3.11/site-packages/neuralforecast/core.py:386, in NeuralForecast.fit(self, df, static_df, val_size, sort_df, use_init_models, verbose, id_col, time_col, target_col, distributed_config)
#     384 # Process and save new dataset (in self)
#     385 if isinstance(df, (pd.DataFrame, pl_DataFrame)):
# --> 386     validate_freq(df[time_col], self.freq)
#     387     self.dataset, self.uids, self.last_dates, self.ds = self._prepare_fit(
#     388         df=df,
#     389         static_df=static_df,
#    (...)
#     394         target_col=target_col,
#     395     )
#     396     self.sort_df = sort_df
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'ds'
